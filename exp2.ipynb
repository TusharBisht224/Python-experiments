# %% [markdown]
# <a href="https://colab.research.google.com/github/TusharBisht224/Python-experiments/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check wether number is positive or negative
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 4
# Positive

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
# Enter a number: 3
# 3 is odd

# %%
num = int(input("Enter a number: "))
if num % 5 == 0:
    print(f"{num} is divisible by 5")
else:
    print(f"{num} is not divisible by 5")
# Out:
# Enter a number: 34
# 34 is not divisible by 5

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
if num1 > num2:
    print(f"{num1} is greater")
elif num2 > num1:
    print(f"{num2} is greater")
else:
    print("Both numbers are equal")
# Out:
# Enter first number: 34
# Enter second number: 53
# 53.0 is greater

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible for voting!")
else:
    print("Not eligible for voting.")
# Out:
# Enter your age: 32
# Eligible for voting!

# %%
num = int(input("Enter a number :"))
if num == 11:
  print("number is equal to 11")
else:
  print("number is not equal to 11")
# Out:
# Enter a number :21
# number is not equal to 11

# %%
# Input three sides
a = int(input("Enter side a: "))
b = int(input("Enter side b: "))
c = int(input("Enter side c: "))

if a + b + c == 180:
    print("Triangle is valid")
elif  a + b + c != 180:
  print("Triangle is invalid")
# Out:
# Enter side a: 2
# Enter side b: 3
# Enter side c: 4
# Triangle is invalid

# %%
a = int(input())
b = int(input())
c = int(input())

if a == b == c:
    print("Equilateral")
elif a == b or b == c or a == c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# 34
# 56
# 87
# Scalene

# %%
num1=float(input("enter past reading: "))
num2=float(input("enter present reading: "))
if num1 > num2:
  print("invalid reading")
else:
  unit= num2 - num1
  bill= unit*8
  print("unit consumed: ", unit)
  print("total bill : ", bill)
# Out:
# enter past reading: 456
# enter present reading: 765
# unit consumed:  309.0
# total bill :  2472.0

# %%
num = int(input())
temp = num
sum = 0

while temp > 0:
    digit = temp % 10
    sum = sum + digit ** 3
    temp = temp // 10

if sum == num:
    print("Armstrong number")
else:
    print("Not Armstrong number")
# Out:
# 3456
# Not Armstrong number

# %%
n = input("enter a string:")
if n == n[::-1]:
  print("Number is palindrome")
else:
  print("Number is not palindrome")
# Out:
# enter a string:3
# Number is palindrome

# %%
n = int(input("enter age of child :"))
if n<5:
  print("Don't give phone to child, give a punishment 20 times ups & downs :")
elif n>5 and n<10 :
  print("Give phone to child only for 30 min and can play offline game, if it will use for more time give then more effective punishment : ")
elif n>10 and n<15:
  print("can use internet for game only:")
elif n>15 and n<18:
  print("can play any game but not for more than 2 hours:")
elif n>18:
  print("can explore anything on internet and can use phone for 8+:")
# Out:
# enter age of child :34
# can explore anything on internet and can use phone for 8+:
